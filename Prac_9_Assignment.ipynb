# %% [markdown]
# <a href="https://colab.research.google.com/github/vidyawadhai13/python-projects/blob/main/Prac_9_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lab Assignment 1: Employee → Manager (Inheritance)
class Employee:
    def __init__(self):
        self.name = ""
        self.age = 0
        self.salary = 0
        self.address = ""

    def get_data(self):
        self.name = input("Enter Name: ")
        self.age = int(input("Enter Age: "))
        self.salary = float(input("Enter Salary: "))
        self.address = input("Enter Address: ")

    def display(self):
        print("\nEmployee Details:")
        print("Name:", self.name)
        print("Age:", self.age)
        print("Salary:", self.salary)
        print("Address:", self.address)


class Manager(Employee):  # Inheriting Employee
    pass


# Process data of 10 managers
managers = []

for i in range(10):
    print(f"\nEnter details for Manager {i+1}")
    m = Manager()
    m.get_data()
    managers.append(m)

print("\n--- Manager Details ---")
for i, m in enumerate(managers):
    print(f"\nManager {i+1}:")
    m.display()
# Out:
# Enter details for Manager 1
# Enter Name: Raj
# Enter Age: 25
# Enter Salary: 60000
# Enter Address: Nagpur
#
# Enter details for Manager 2
# Enter Name: Moni
# Enter Age: 24
# Enter Salary: 60000
# Enter Address: Banglore
#
# Enter details for Manager 3
# Enter Name: Viraj
# Enter Age: 30
# Enter Salary: 750000
# Enter Address: Mumbai
#
# Enter details for Manager 4
# Enter Name: Gauri
# Enter Age: 26
# Enter Salary: 720000
# Enter Address: Jaipur
#
# Enter details for Manager 5
# Enter Name: Archana
# Enter Age: 25
# Enter Salary: 80000
# Enter Address: Pune
#
# Enter details for Manager 6
# Enter Name: Sayli
# Enter Age: 24
# Enter Salary: 55000
# Enter Address: Hyderabad
#
# Enter details for Manager 7
# Enter Name: Rohan
# Enter Age: 24
# Enter Salary: 55000
# Enter Address: Hyderabad
#
# Enter details for Manager 8
# Enter Name: Karthik
# Enter Age: 26
# Enter Salary: 60000
# Enter Address: Kolkata
#
# Enter details for Manager 9
# Enter Name: Tanya
# Enter Age: 26
# ...

# %%
# Lab Assignment 2: Library Management System (Menu Driven)
class Book:
    def __init__(self, book_id, title):
        self.book_id = book_id
        self.title = title
        self.available = True


class Member:
    def __init__(self, member_id, name):
        self.member_id = member_id
        self.name = name


class Library:
    def __init__(self):
        self.books = []
        self.members = []

    def add_book(self):
        book_id = input("Enter Book ID: ")
        title = input("Enter Book Title: ")
        self.books.append(Book(book_id, title))
        print("Book added successfully!")

    def add_member(self):
        member_id = input("Enter Member ID: ")
        name = input("Enter Member Name: ")
        self.members.append(Member(member_id, name))
        print("Member added successfully!")

    def lend_book(self):
        book_id = input("Enter Book ID to lend: ")
        for book in self.books:
            if book.book_id == book_id:
                if book.available:
                    book.available = False
                    print("Book lent successfully!")
                else:
                    print("Book is already lent.")
                return
        print("Book not found.")

    def return_book(self):
        book_id = input("Enter Book ID to return: ")
        for book in self.books:
            if book.book_id == book_id:
                book.available = True
                print("Book returned successfully!")
                return
        print("Book not found.")

    def display_books(self):
        print("\nLibrary Books:")
        for book in self.books:
            status = "Available" if book.available else "Lent"
            print(f"ID: {book.book_id}, Title: {book.title}, Status: {status}")


# Menu Driven Program
library = Library()

while True:
    print("\n--- Library Menu ---")
    print("1. Add Book")
    print("2. Add Member")
    print("3. Lend Book")
    print("4. Return Book")
    print("5. Display Books")
    print("6. Exit")

    choice = input("Enter choice: ")

    if choice == '1':
        library.add_book()
    elif choice == '2':
        library.add_member()
    elif choice == '3':
        library.lend_book()
    elif choice == '4':
        library.return_book()
    elif choice == '5':
        library.display_books()
    elif choice == '6':
        print("Exiting...")
        break
    else:
        print("Invalid choice!")
# Out:
# --- Library Menu ---
# 1. Add Book
# 2. Add Member
# 3. Lend Book
# 4. Return Book
# 5. Display Books
# 6. Exit
# Enter choice: 1
# Enter Book ID: 101
# Enter Book Title: Python Basics
# Book added successfully!
#
# --- Library Menu ---
# 1. Add Book
# 2. Add Member
# 3. Lend Book
# 4. Return Book
# 5. Display Books
# 6. Exit
# Enter choice: 1
# Enter Book ID: 102
# Enter Book Title: Data Structure
# Book added successfully!
#
# --- Library Menu ---
# 1. Add Book
# 2. Add Member
# 3. Lend Book
# 4. Return Book
# 5. Display Books
# 6. Exit
# Enter choice: 5
#
# Library Books:
# ID: 101, Title: Python Basics, Status: Available
# ID: 102, Title: Data Structure, Status: Available
#
# --- Library Menu ---
# 1. Add Book
# 2. Add Member
# 3. Lend Book
# 4. Return Book
# 5. Display Books
# 6. Exit
# Enter choice: 3
# Enter Book ID to lend: 101
# Book lent successfully!
#
# --- Library Menu ---
# 1. Add Book
# 2. Add Member
# 3. Lend Book
# 4. Return Book
# 5. Display Books
# 6. Exit
# ...
