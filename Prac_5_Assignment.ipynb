# %% [markdown]
# <a href="https://colab.research.google.com/github/vidyawadhai13/python-projects/blob/main/Prac_5_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assignment-1
# Take series of integers from user and store in tuple
numbers = tuple(map(int, input("Enter integers separated by space: ").split()))

print("\nTuple:", numbers)

# a) Total number of items
print("Total number of items:", len(numbers))

# b) Last item in tuple
print("Last item in tuple:", numbers[-1])

# c) Tuple elements in reverse order
print("Tuple in reverse order:", numbers[::-1])

# d) Check if 5 is present
if 5 in numbers:
    print("Yes, 5 is present in the tuple.")
else:
    print("No, 5 is not present in the tuple.")

# e) Remove first and last items, sort remaining, print result
if len(numbers) > 2:
    remaining = numbers[1:-1]     # Remove first and last
    sorted_remaining = tuple(sorted(remaining))
    print("After removing first & last and sorting:", sorted_remaining)
else:
    print("Not enough elements to remove first and last.")
# Out:
# Enter integers separated by space: 15 20 25 30
#
# Tuple: (15, 20, 25, 30)
# Total number of items: 4
# Last item in tuple: 30
# Tuple in reverse order: (30, 25, 20, 15)
# No, 5 is not present in the tuple.
# After removing first & last and sorting: (20, 25)

# %%
# Assignment-2
# Store prices of sold items in a tuple
prices = tuple(map(float, input("Enter prices of sold items separated by space: ").split()))

print("\nPrices:", prices)

# a) Total number of items sold
print("Total number of items sold:", len(prices))

# b) Cheapest item price
cheapest = min(prices)
print("Cheapest item price:", cheapest)

# c) Costliest item price
costliest = max(prices)
print("Costliest item price:", costliest)

# d) Price list in ascending order
print("Prices in ascending order:", tuple(sorted(prices)))

# e) Number of costliest items sold
count_costliest = prices.count(costliest)
print("Number of costliest items sold:", count_costliest)
# Out:
# Enter prices of sold items separated by space: 1200 500 1500 2000
#
# Prices: (1200.0, 500.0, 1500.0, 2000.0)
# Total number of items sold: 4
# Cheapest item price: 500.0
# Costliest item price: 2000.0
# Prices in ascending order: (500.0, 1200.0, 1500.0, 2000.0)
# Number of costliest items sold: 1
